# %% [markdown]
# # Demographic Data Analyzer

# %% [markdown]
# Load dataset

# %%
# %config IPCompleter.greedy=True

# %%
import pandas as pd

# %%
df = pd.read_csv('./adult.data.csv')

# %%
df.head(5)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %% [markdown]
# ### How many people of each race are represented in this dataset? This should be a Pandas series with race names as the index labels. (`race` column)

# %%
race = df['race']

# %%
race_count = race.groupby(race).count()

# %%
race_count
# Out:
# race
# Amer-Indian-Eskimo      311
# Asian-Pac-Islander     1039
# Black                  3124
# Other                   271
# White                 27816
# Name: race, dtype: int64

# %%
race_count = race_count.tolist()

# %%
race_count
# Out:
# [311, 1039, 3124, 271, 27816]

# %%
race_count.sort(reverse=True)

# %%
race_count
# Out:
# [27816, 3124, 1039, 311, 271]

# %% [markdown]
# ### What is the average age of men?

# %%
df.query("sex == 'Male' ")['age'].mean().round(1)
# Out:
# 39.4

# %% [markdown]
# ### What is the percentage of people who have a Bachelor's degree?

# %%
total = df['education'].count()

# %%
percentage_bachelors = df.query("education == 'Bachelors'").count().education * 100 / total

# %%
percentage_bachelors = percentage_bachelors.round(1)

# %%
percentage_bachelors
# Out:
# 16.4

# %% [markdown]
# ### What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?

# %%
people_with_adv_ed_and_hig_salary = df.query("(education =='Bachelors' or education == 'Masters' or education == 'Doctorate') and salary == '>50K' ") 
people_with_adv_ed_and_hig_salary
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 8       31           Private   45781    Masters             14
# 9       42           Private  159449  Bachelors             13
# 11      30         State-gov  141297  Bachelors             13
# 19      43  Self-emp-not-inc  292175    Masters             14
# 20      40           Private  193524  Doctorate             16
# ...    ...               ...     ...        ...            ...
# 32533   54           Private  337992  Bachelors             13
# 32536   34           Private  160216  Bachelors             13
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 8           Never-married   Prof-specialty  Not-in-family               White
# 9      Married-civ-spouse  Exec-managerial        Husband               White
# 11     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# 19               Divorced  Exec-managerial      Unmarried               White
# 20     Married-civ-spouse   Prof-specialty        Husband               White
# ...                   ...              ...            ...                 ...
# 32533  Married-civ-spouse  Exec-managerial        Husband  Asian-Pac-Islander
# 32536       Never-married  Exec-managerial  Not-in-family               White
# 32538            Divorced   Prof-specialty      Unmarried               Black
# 32539  Married-civ-spouse                ?        Husband               White
# 32554  Married-civ-spouse  Exec-managerial        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 8      Female         14084             0              50  United-States
# 9        Male          5178             0              40  United-States
# 11       Male             0             0              40          India
# 19     Female             0             0              45  United-States
# 20       Male             0             0              60  United-States
# ...       ...           ...           ...             ...            ...
# 32533    Male             0             0              50          Japan
# 32536  Female             0             0              55  United-States
# 32538  Female         15020             0              45  United-States
# 32539    Male             0             0              10  United-States
# 32554    Male             0             0              40  United-States
#
#       salary
# 8       >50K
# 9       >50K
# 11      >50K
# 19      >50K
# 20      >50K
# ...      ...
# 32533   >50K
# 32536   >50K
# 32538   >50K
# 32539   >50K
# 32554   >50K
#
# [3486 rows x 15 columns]

# %%
people_with_adv_ed = df.query("(education =='Bachelors' or education == 'Masters' or education == 'Doctorate') ") 
people_with_adv_ed
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 4       28           Private  338409  Bachelors             13
# 5       37           Private  284582    Masters             14
# 8       31           Private   45781    Masters             14
# ...    ...               ...     ...        ...            ...
# 32538   38           Private  139180  Bachelors             13
# 32539   71                 ?  287372  Doctorate             16
# 32544   31           Private  199655    Masters             14
# 32553   32           Private  116138    Masters             14
# 32554   53           Private  321865    Masters             14
#
#            marital-status       occupation   relationship                race  \
# 0           Never-married     Adm-clerical  Not-in-family               White
# 1      Married-civ-spouse  Exec-managerial        Husband               White
# 4      Married-civ-spouse   Prof-specialty           Wife               Black
# 5      Married-civ-spouse  Exec-managerial           Wife               White
# 8           Never-married   Prof-specialty  Not-in-family               White
# ...                   ...              ...            ...                 ...
# 32538            Divorced   Prof-specialty      Unmarried               Black
# 32539  Married-civ-spouse                ?        Husband               White
# 32544            Divorced    Other-service  Not-in-family               Other
# 32553       Never-married     Tech-support  Not-in-family  Asian-Pac-Islander
# 32554  Married-civ-spouse  Exec-managerial        Husband               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 0        Male          2174             0              40  United-States
# 1        Male             0             0              13  United-States
# 4      Female             0             0              40           Cuba
# 5      Female             0             0              40  United-States
# 8      Female         14084             0              50  United-States
# ...       ...           ...           ...             ...            ...
# 32538  Female         15020             0              45  United-States
# 32539    Male             0             0              10  United-States
# 32544  Female             0             0              30  United-States
# 32553    Male             0             0              11         Taiwan
# 32554    Male             0             0              40  United-States
#
#       salary
# 0      <=50K
# 1      <=50K
# 4      <=50K
# 5      <=50K
# 8       >50K
# ...      ...
# 32538   >50K
# 32539   >50K
# 32544  <=50K
# 32553  <=50K
# 32554   >50K
#
# [7491 rows x 15 columns]

# %%
higher_education_rich = people_with_adv_ed_and_hig_salary.count().education * 100/ people_with_adv_ed.count().education

# %%
higher_education_rich = higher_education_rich.round(1)

# %%
higher_education_rich
# Out:
# 46.5

# %% [markdown]
# ### What percentage of people without advanced education make more than 50K

# %%
people_without_adv_ed = df.query("not (education =='Bachelors' or education == 'Masters' or education == 'Doctorate') ")

# %%
total = people_without_adv_ed.count().education

# %%
total
# Out:
# 25070

# %%
people_without_adv_ed_and_hig_salary = df.query("not (education =='Bachelors' or education == 'Masters' or education == 'Doctorate') and salary == '>50K' ") 
people_without_adv_ed_and_hig_salary
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# 14      40           Private  121772     Assoc-voc             11
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32518   57         Local-gov  110417       HS-grad              9
# 32519   46           Private  364548  Some-college             10
# 32545   39         Local-gov  111499    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#            marital-status         occupation relationship                race  \
# 7      Married-civ-spouse    Exec-managerial      Husband               White
# 10     Married-civ-spouse    Exec-managerial      Husband               Black
# 14     Married-civ-spouse       Craft-repair      Husband  Asian-Pac-Islander
# 27     Married-civ-spouse                  ?      Husband  Asian-Pac-Islander
# 38     Married-civ-spouse              Sales      Husband               White
# ...                   ...                ...          ...                 ...
# 32518  Married-civ-spouse       Craft-repair      Husband               White
# 32519  Married-civ-spouse    Exec-managerial      Husband               White
# 32545  Married-civ-spouse       Adm-clerical         Wife               White
# 32557  Married-civ-spouse  Machine-op-inspct      Husband               White
# 32560  Married-civ-spouse    Exec-managerial         Wife               White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country  \
# 7        Male             0             0              45  United-States
# 10       Male             0             0              80  United-States
# 14       Male             0             0              40              ?
# 27       Male             0             0              60          South
# 38       Male             0             0              38              ?
# ...       ...           ...           ...             ...            ...
# 32518    Male         99999             0              40  United-States
# 32519    Male             0             0              48  United-States
# 32545  Female             0             0              20  United-States
# 32557    Male             0             0              40  United-States
# 32560  Female         15024             0              40  United-States
#
#       salary
# 7       >50K
# 10      >50K
# 14      >50K
# 27      >50K
# 38      >50K
# ...      ...
# 32518   >50K
# 32519   >50K
# 32545   >50K
# 32557   >50K
# 32560   >50K
#
# [4355 rows x 15 columns]

# %%
without_education = people_without_adv_ed_and_hig_salary.count().education

# %%
without_education
# Out:
# 4355

# %%
lower_education_rich = without_education * 100 / total

# %%
lower_education_rich = lower_education_rich.round(1)

# %%
lower_education_rich
# Out:
# 17.4

# %% [markdown]
# ### What is the minimum number of hours a person works per week?

# %%
min_work_hours= df['hours-per-week'].min()

# %%
min_work_hours
# Out:
# 1

# %% [markdown]
# ### What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?

# %%
people_mim_hour_week_and_hig_salary = df[df['hours-per-week'] == min_work_hours].query("salary == '>50K'")

# %%
people_mim_hour_week_and_hig_salary
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 189     58  State-gov  109567  Doctorate             16  Married-civ-spouse
# 20072   65          ?   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   race   sex  capital-gain  capital-loss  \
# 189    Prof-specialty      Husband  White  Male             0             0
# 20072               ?      Husband  White  Male             0             0
#
#        hours-per-week native-country salary
# 189                 1  United-States   >50K
# 20072               1  United-States   >50K

# %%
people_mim_hour_week = df[df['hours-per-week'] == min_work_hours]

# %%
people_mim_hour_week
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 189     58         State-gov  109567     Doctorate             16
# 1036    66      Self-emp-inc  150726           9th              5
# 1262    69                 ?  195779     Assoc-voc             11
# 5590    78                 ?  363134       HS-grad              9
# 5632    45                 ?  189564       Masters             14
# 5766    62                 ?   97231  Some-college             10
# 5808    76                 ?  211574          10th              6
# 8447    67                 ?  244122     Assoc-voc             11
# 9147    75                 ?  260543          10th              6
# 11451   27           Private  147951       HS-grad              9
# 19337   72                 ?   76860       HS-grad              9
# 19750   23           Private   72887       HS-grad              9
# 20072   65                 ?   76043       HS-grad              9
# 20909   77  Self-emp-not-inc   71676  Some-college             10
# 22960   21           Private  184135       HS-grad              9
# 23536   69                 ?  320280  Some-college             10
# 24284   57  Self-emp-not-inc   56480       HS-grad              9
# 25078   74           Private  260669          10th              6
# 29752   69                 ?  117525    Assoc-acdm             12
# 32525   81                 ?  120478     Assoc-voc             11
#
#            marital-status         occupation    relationship  \
# 189    Married-civ-spouse     Prof-specialty         Husband
# 1036   Married-civ-spouse    Exec-managerial         Husband
# 1262              Widowed                  ?   Not-in-family
# 5590              Widowed                  ?   Not-in-family
# 5632   Married-civ-spouse                  ?            Wife
# 5766   Married-civ-spouse                  ?            Wife
# 5808   Married-civ-spouse                  ?         Husband
# 8447              Widowed                  ?   Not-in-family
# 9147              Widowed                  ?  Other-relative
# 11451       Never-married  Machine-op-inspct  Other-relative
# 19337  Married-civ-spouse                  ?         Husband
# 19750       Never-married       Craft-repair       Own-child
# 20072  Married-civ-spouse                  ?         Husband
# 20909             Widowed       Adm-clerical   Not-in-family
# 22960       Never-married  Machine-op-inspct       Own-child
# 23536       Never-married                  ?   Not-in-family
# 24284  Married-civ-spouse    Exec-managerial         Husband
# 25078            Divorced      Other-service   Not-in-family
# 29752            Divorced                  ?       Unmarried
# 32525            Divorced                  ?       Unmarried
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 189                 White    Male             0             0               1
# 1036                White    Male          1409             0               1
# 1262                White  Female             0             0               1
# 5590                White  Female             0             0               1
# 5632                White  Female             0             0               1
# 5766                White  Female             0             0               1
# 5808                White    Male             0             0               1
# 8447                White  Female             0             0               1
# 9147   Asian-Pac-Islander  Female             0             0               1
# 11451               White    Male             0             0               1
# 19337  Asian-Pac-Islander    Male             0             0               1
# 19750  Asian-Pac-Islander    Male             0             0               1
# 20072               White    Male             0             0               1
# 20909               White  Female             0          1944               1
# 22960               Black    Male             0             0               1
# 23536               White    Male          1848             0               1
# 24284               White    Male             0             0               1
# 25078               White  Female             0             0               1
# 29752               White  Female             0             0               1
# 32525               White  Female             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 1036               ?  <=50K
# 1262   United-States  <=50K
# 5590   United-States  <=50K
# 5632   United-States  <=50K
# 5766   United-States  <=50K
# 5808   United-States  <=50K
# 8447   United-States  <=50K
# 9147           China  <=50K
# 11451  United-States  <=50K
# 19337  United-States  <=50K
# 19750        Vietnam  <=50K
# 20072  United-States   >50K
# 20909  United-States  <=50K
# 22960  United-States  <=50K
# 23536  United-States  <=50K
# 24284  United-States  <=50K
# 25078  United-States  <=50K
# 29752  United-States  <=50K
# 32525              ?  <=50K

# %%
rich_percentage = people_mim_hour_week_and_hig_salary.count().education * 100 / people_mim_hour_week.count().education
rich_percentage
# Out:
# 10.0

# %% [markdown]
# ### What country has the highest percentage of people that earn >50K and what is that percentage?

# %%
#highest_earning_country


grouped = df.groupby(["native-country"])['salary'].agg('count')

# %%
type(grouped)
# Out:
# pandas.core.series.Series

# %%
total_people_country = grouped.to_frame(name= 'total_people')

# %%
total_people_country['country'] = total_people_country.index

# %%
total_people_country
# Out:
#                             total_people                     country
# native-country
# ?                                    583                           ?
# Cambodia                              19                    Cambodia
# Canada                               121                      Canada
# China                                 75                       China
# Columbia                              59                    Columbia
# Cuba                                  95                        Cuba
# Dominican-Republic                    70          Dominican-Republic
# Ecuador                               28                     Ecuador
# El-Salvador                          106                 El-Salvador
# England                               90                     England
# France                                29                      France
# Germany                              137                     Germany
# Greece                                29                      Greece
# Guatemala                             64                   Guatemala
# Haiti                                 44                       Haiti
# Holand-Netherlands                     1          Holand-Netherlands
# Honduras                              13                    Honduras
# Hong                                  20                        Hong
# Hungary                               13                     Hungary
# India                                100                       India
# Iran                                  43                        Iran
# Ireland                               24                     Ireland
# Italy                                 73                       Italy
# Jamaica                               81                     Jamaica
# Japan                                 62                       Japan
# Laos                                  18                        Laos
# Mexico                               643                      Mexico
# Nicaragua                             34                   Nicaragua
# Outlying-US(Guam-USVI-etc)            14  Outlying-US(Guam-USVI-etc)
# Peru                                  31                        Peru
# Philippines                          198                 Philippines
# Poland                                60                      Poland
# Portugal                              37                    Portugal
# Puerto-Rico                          114                 Puerto-Rico
# Scotland                              12                    Scotland
# South                                 80                       South
# Taiwan                                51                      Taiwan
# Thailand                              18                    Thailand
# Trinadad&Tobago                       19             Trinadad&Tobago
# United-States                      29170               United-States
# Vietnam                               67                     Vietnam
# Yugoslavia                            16                  Yugoslavia

# %%
grouped_salary = df.groupby(['native-country' , 'salary'])['native-country'].agg('count')

# %%
total_people_salary = grouped_salary.to_frame()

# %%
 type (total_people_salary.unstack(level='salary'))
# Out:
# pandas.core.frame.DataFrame

# %%
total_salary_country = total_people_salary.unstack(level='salary')

# %%
total_salary_country['country'] = total_salary_country.index

# %%
total_salary_country
# Out:
#                            native-country                             country
# salary                              <=50K    >50K
# native-country
# ?                                   437.0   146.0                           ?
# Cambodia                             12.0     7.0                    Cambodia
# Canada                               82.0    39.0                      Canada
# China                                55.0    20.0                       China
# Columbia                             57.0     2.0                    Columbia
# Cuba                                 70.0    25.0                        Cuba
# Dominican-Republic                   68.0     2.0          Dominican-Republic
# Ecuador                              24.0     4.0                     Ecuador
# El-Salvador                          97.0     9.0                 El-Salvador
# England                              60.0    30.0                     England
# France                               17.0    12.0                      France
# Germany                              93.0    44.0                     Germany
# Greece                               21.0     8.0                      Greece
# Guatemala                            61.0     3.0                   Guatemala
# Haiti                                40.0     4.0                       Haiti
# Holand-Netherlands                    1.0     NaN          Holand-Netherlands
# Honduras                             12.0     1.0                    Honduras
# Hong                                 14.0     6.0                        Hong
# Hungary                              10.0     3.0                     Hungary
# India                                60.0    40.0                       India
# Iran                                 25.0    18.0                        Iran
# Ireland                              19.0     5.0                     Ireland
# Italy                                48.0    25.0                       Italy
# Jamaica                              71.0    10.0                     Jamaica
# Japan                                38.0    24.0                       Japan
# Laos                                 16.0     2.0                        Laos
# Mexico                              610.0    33.0                      Mexico
# Nicaragua                            32.0     2.0                   Nicaragua
# Outlying-US(Guam-USVI-etc)           14.0     NaN  Outlying-US(Guam-USVI-etc)
# Peru                                 29.0     2.0                        Peru
# Philippines                         137.0    61.0                 Philippines
# Poland                               48.0    12.0                      Poland
# Portugal                             33.0     4.0                    Portugal
# Puerto-Rico                         102.0    12.0                 Puerto-Rico
# Scotland                              9.0     3.0                    Scotland
# South                                64.0    16.0                       South
# Taiwan                               31.0    20.0                      Taiwan
# Thailand                             15.0     3.0                    Thailand
# Trinadad&Tobago                      17.0     2.0             Trinadad&Tobago
# United-States                     21999.0  7171.0               United-States
# Vietnam                              62.0     5.0                     Vietnam
# Yugoslavia                           10.0     6.0                  Yugoslavia

# %%
total_salary_salary_50K = total_salary_country[('native-country')]['>50K'].values
total_salary_salary_menor_50K = total_salary_country[('native-country')]['<=50K'].values

# %%
total_people_country['>50K'] = total_salary_salary_50K
total_people_country['<=50K'] = total_salary_salary_menor_50K

# %%
total_people_country
# Out:
#                             total_people                     country    >50K  \
# native-country
# ?                                    583                           ?   146.0
# Cambodia                              19                    Cambodia     7.0
# Canada                               121                      Canada    39.0
# China                                 75                       China    20.0
# Columbia                              59                    Columbia     2.0
# Cuba                                  95                        Cuba    25.0
# Dominican-Republic                    70          Dominican-Republic     2.0
# Ecuador                               28                     Ecuador     4.0
# El-Salvador                          106                 El-Salvador     9.0
# England                               90                     England    30.0
# France                                29                      France    12.0
# Germany                              137                     Germany    44.0
# Greece                                29                      Greece     8.0
# Guatemala                             64                   Guatemala     3.0
# Haiti                                 44                       Haiti     4.0
# Holand-Netherlands                     1          Holand-Netherlands     NaN
# Honduras                              13                    Honduras     1.0
# Hong                                  20                        Hong     6.0
# Hungary                               13                     Hungary     3.0
# India                                100                       India    40.0
# Iran                                  43                        Iran    18.0
# Ireland                               24                     Ireland     5.0
# Italy                                 73                       Italy    25.0
# Jamaica                               81                     Jamaica    10.0
# Japan                                 62                       Japan    24.0
# Laos                                  18                        Laos     2.0
# Mexico                               643                      Mexico    33.0
# Nicaragua                             34                   Nicaragua     2.0
# Outlying-US(Guam-USVI-etc)            14  Outlying-US(Guam-USVI-etc)     NaN
# Peru                                  31                        Peru     2.0
# Philippines                          198                 Philippines    61.0
# Poland                                60                      Poland    12.0
# Portugal                              37                    Portugal     4.0
# Puerto-Rico                          114                 Puerto-Rico    12.0
# Scotland                              12                    Scotland     3.0
# South                                 80                       South    16.0
# Taiwan                                51                      Taiwan    20.0
# Thailand                              18                    Thailand     3.0
# Trinadad&Tobago                       19             Trinadad&Tobago     2.0
# United-States                      29170               United-States  7171.0
# Vietnam                               67                     Vietnam     5.0
# Yugoslavia                            16                  Yugoslavia     6.0
#
#                               <=50K
# native-country
# ?                             437.0
# Cambodia                       12.0
# Canada                         82.0
# China                          55.0
# Columbia                       57.0
# Cuba                           70.0
# Dominican-Republic             68.0
# Ecuador                        24.0
# El-Salvador                    97.0
# England                        60.0
# France                         17.0
# Germany                        93.0
# Greece                         21.0
# Guatemala                      61.0
# Haiti                          40.0
# Holand-Netherlands              1.0
# Honduras                       12.0
# Hong                           14.0
# Hungary                        10.0
# India                          60.0
# Iran                           25.0
# Ireland                        19.0
# Italy                          48.0
# Jamaica                        71.0
# Japan                          38.0
# Laos                           16.0
# Mexico                        610.0
# Nicaragua                      32.0
# Outlying-US(Guam-USVI-etc)     14.0
# Peru                           29.0
# Philippines                   137.0
# Poland                         48.0
# Portugal                       33.0
# Puerto-Rico                   102.0
# Scotland                        9.0
# South                          64.0
# Taiwan                         31.0
# Thailand                       15.0
# Trinadad&Tobago                17.0
# United-States               21999.0
# Vietnam                        62.0
# Yugoslavia                     10.0

# %%
total_people_country['pergentage_high'] = total_people_country['>50K'] * 100/ total_people_country['total_people']

# %%
total_people_country['pergentage_low'] = total_people_country['<=50K'] * 100/ total_people_country['total_people']

# %%
total_people_country
# Out:
#                             total_people                     country    >50K  \
# native-country
# ?                                    583                           ?   146.0
# Cambodia                              19                    Cambodia     7.0
# Canada                               121                      Canada    39.0
# China                                 75                       China    20.0
# Columbia                              59                    Columbia     2.0
# Cuba                                  95                        Cuba    25.0
# Dominican-Republic                    70          Dominican-Republic     2.0
# Ecuador                               28                     Ecuador     4.0
# El-Salvador                          106                 El-Salvador     9.0
# England                               90                     England    30.0
# France                                29                      France    12.0
# Germany                              137                     Germany    44.0
# Greece                                29                      Greece     8.0
# Guatemala                             64                   Guatemala     3.0
# Haiti                                 44                       Haiti     4.0
# Holand-Netherlands                     1          Holand-Netherlands     NaN
# Honduras                              13                    Honduras     1.0
# Hong                                  20                        Hong     6.0
# Hungary                               13                     Hungary     3.0
# India                                100                       India    40.0
# Iran                                  43                        Iran    18.0
# Ireland                               24                     Ireland     5.0
# Italy                                 73                       Italy    25.0
# Jamaica                               81                     Jamaica    10.0
# Japan                                 62                       Japan    24.0
# Laos                                  18                        Laos     2.0
# Mexico                               643                      Mexico    33.0
# Nicaragua                             34                   Nicaragua     2.0
# Outlying-US(Guam-USVI-etc)            14  Outlying-US(Guam-USVI-etc)     NaN
# Peru                                  31                        Peru     2.0
# Philippines                          198                 Philippines    61.0
# Poland                                60                      Poland    12.0
# Portugal                              37                    Portugal     4.0
# Puerto-Rico                          114                 Puerto-Rico    12.0
# Scotland                              12                    Scotland     3.0
# South                                 80                       South    16.0
# Taiwan                                51                      Taiwan    20.0
# Thailand                              18                    Thailand     3.0
# Trinadad&Tobago                       19             Trinadad&Tobago     2.0
# United-States                      29170               United-States  7171.0
# Vietnam                               67                     Vietnam     5.0
# Yugoslavia                            16                  Yugoslavia     6.0
#
#                               <=50K  pergentage_high  pergentage_low
# native-country
# ?                             437.0        25.042882       74.957118
# Cambodia                       12.0        36.842105       63.157895
# Canada                         82.0        32.231405       67.768595
# China                          55.0        26.666667       73.333333
# Columbia                       57.0         3.389831       96.610169
# Cuba                           70.0        26.315789       73.684211
# Dominican-Republic             68.0         2.857143       97.142857
# Ecuador                        24.0        14.285714       85.714286
# El-Salvador                    97.0         8.490566       91.509434
# England                        60.0        33.333333       66.666667
# France                         17.0        41.379310       58.620690
# Germany                        93.0        32.116788       67.883212
# Greece                         21.0        27.586207       72.413793
# Guatemala                      61.0         4.687500       95.312500
# Haiti                          40.0         9.090909       90.909091
# Holand-Netherlands              1.0              NaN      100.000000
# Honduras                       12.0         7.692308       92.307692
# Hong                           14.0        30.000000       70.000000
# Hungary                        10.0        23.076923       76.923077
# India                          60.0        40.000000       60.000000
# Iran                           25.0        41.860465       58.139535
# Ireland                        19.0        20.833333       79.166667
# Italy                          48.0        34.246575       65.753425
# Jamaica                        71.0        12.345679       87.654321
# Japan                          38.0        38.709677       61.290323
# Laos                           16.0        11.111111       88.888889
# Mexico                        610.0         5.132193       94.867807
# Nicaragua                      32.0         5.882353       94.117647
# Outlying-US(Guam-USVI-etc)     14.0              NaN      100.000000
# Peru                           29.0         6.451613       93.548387
# Philippines                   137.0        30.808081       69.191919
# Poland                         48.0        20.000000       80.000000
# Portugal                       33.0        10.810811       89.189189
# Puerto-Rico                   102.0        10.526316       89.473684
# Scotland                        9.0        25.000000       75.000000
# South                          64.0        20.000000       80.000000
# Taiwan                         31.0        39.215686       60.784314
# Thailand                       15.0        16.666667       83.333333
# Trinadad&Tobago                17.0        10.526316       89.473684
# United-States               21999.0        24.583476       75.416524
# Vietnam                        62.0         7.462687       92.537313
# Yugoslavia                     10.0        37.500000       62.500000

# %%
total_people_country[total_people_country.pergentage_high ==total_people_country.pergentage_high.max()].country[0]
# Out:
# 'Iran'

# %%
highest_earning_country = total_people_country[total_people_country.pergentage_high ==total_people_country.pergentage_high.max()].country[0]

# %%
highest_earning_country_percentage = total_people_country.pergentage_high.max().round(1)
highest_earning_country_percentage
# Out:
# 41.9

# %% [markdown]
# ### Identify the most popular occupation for those who earn >50K in India.

# %%
df= df.rename(columns= {'native-country': 'country'})

# %%
occupations = df.query("salary == '>50K' and country == 'India'").groupby('occupation')['salary'].count()

# %%
type(occupations)
# Out:
# pandas.core.series.Series

# %%
occupations= occupations.to_frame(name=None)

# %%
occupations['occupations'] = occupations.index

# %%
top_IN_occupation = occupations[occupations.salary == occupations.salary.max()]['occupations'][0]

# %%
top_IN_occupation
# Out:
# 'Prof-specialty'
